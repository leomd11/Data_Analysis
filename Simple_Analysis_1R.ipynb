# %% [markdown]
# <a href="https://colab.research.google.com/github/leomd11/Data_Analysis/blob/master/Simple_Analysis_1R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Análise exploratória de dados 1. By Prof. Márion Chaves

# %%
# Criar o data frame contendo o histórico de vendas de café

dados <- data.frame (
  Vendas_Cafe = c(18, 20, 23, 23, 23, 23, 24, 25, 26, 26, 26, 26, 27, 28, 28, 29, 29, 30, 30, 31, 31, 33, 34, 35, 38, 39, 41, 44, 44, 46),
  Preco_Cafe = c(4.77, 4.67, 4.75, 4.74, 4.63, 4.56, 4.59, 4.75, 4.75, 4.49,4.41, 4.32, 4.68, 4.66, 4.42, 4.71, 4.66, 4.46, 4.36, 4.47, 4.43, 
  4.4, 4.61, 4.09, 3.73, 3.89, 4.35, 3.84, 3.81, 3.79),
  Promocao = c("Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim", "Nao", "Sim", "Nao", "Nao", "Sim", "Sim", "Nao", "Sim", "Sim", 
  "Sim", "Nao", "Nao", "Sim", "Sim", "Sim", "Nao", "Sim", "Sim", "Sim", "Sim", "Sim"),
  Preco_Leite = c(4.74, 4.81, 4.36, 4.29, 4.17, 4.66, 4.73, 4.11, 4.21, 4.25, 4.62, 4.53, 4.44, 4.19, 4.37, 4.29, 4.57, 4.21, 4.77, 4, 4.31, 
  4.34, 4.05, 4.73, 4.07, 4.75, 4, 4.15, 4.34, 4.15))

# %%
# Visualizar a média e outras estatísticas descritivas das variáveis

summary (dados)
# Out:
#   Vendas_Cafe      Preco_Cafe      Promocao          Preco_Leite
#  Min.   :18.00   Min.   :3.730   Length:30          Min.   :4.000
#  1st Qu.:25.25   1st Qu.:4.353   Class :character   1st Qu.:4.175
#  Median :28.50   Median :4.480   Mode  :character   Median :4.325
#  Mean   :30.00   Mean   :4.426                      Mean   :4.374
#  3rd Qu.:33.75   3rd Qu.:4.668                      3rd Qu.:4.607
#  Max.   :46.00   Max.   :4.770                      Max.   :4.810

# %%
# Visualizar o desvio padrão das variáveis 

sd(dados$Vendas_Cafe)
sd(dados$Preco_Cafe)
sd(dados$Preco_Leite)
# Out:
# [1] 7.310833
# [1] 0.3220568
# [1] 0.2558082

# %%
# Visualizar por meio de um histograma a distribuição da variável Preco_Cafe

hist(dados$Preco_Cafe)
# Out:
# Plot with title “Histogram of dados$Preco_Cafe”

# %%
# Customizando o histograma, colocando título e mudando a cor das colunas

hist(dados$Preco_Cafe,
    col = 'blue',
    main = 'Distribuição dos Preços Praticados para o Café')
# Out:
# Plot with title “Distribuição dos Preços Praticados para o Café”

# %%
# Visualizar o histograma das três variáveis numéricas nas mesma página

#par(mfrow = c(2,2))

# Configura layout para posicionar os gráficos em duas linhas e duas colunas

hist(dados$Vendas_Cafe,
    col = 'blue',
    main = ' Distribuição das Vendas do Café')

hist(dados$Preco_Cafe,
    col = 'blue',
    main = 'Distribuição dos Preços do Café')

hist(dados$Preco_Leite,
    col = 'blue',
    main = 'Distribuição dos Preços do Leite')
# Out:
# Plot with title “Distribuição dos Preços do Leite”

# %%
plot(y = dados$Vendas_Cafe,
     x = dados$Preco_Cafe)
# Out:
# plot without title

# %%
# Customizando o gráfico

plot(y = dados$Vendas_Cafe,
     x = dados$Preco_Cafe,
     pch = 16,
     col = 'blue',
     xlab = 'Preço',
     ylab = 'Quantidade Vendida',
     main = 'Relação entre o Preço e as Vendas do Café')
grid()
# Out:
# Plot with title “Relação entre o Preço e as Vendas do Café”

# %%
# Colorir os pontos em que havia promoção

plot(y = dados$Vendas_Cafe,
     x = dados$Preco_Cafe,
     pch = 16,
     xlab = 'Preço',
     col = factor(dados$Promocao),
     ylab = 'Quantidade Vendida',
     main = 'Relação entre o preço e as vendas do café')
  legend(x=4.4, y=45,
        c("Promoção","Sem_Promoção"),
        col = c("red","black"),
        pch=c(16,16))
    grid()
# Out:
# Plot with title “Relação entre o preço e as vendas do café”

# %%
# Cria uma nova variável informando se naquele dia vendeu acima ou abaixo da média histórica

# Armazenando em uma variável
media <- mean(dados$Vendas_Cafe)

variavel <- ifelse(dados$Vendas_Cafe > media,
            'Acima_da_media',
            'Abaixo_da_media')

# Converte a nova variavel para factor
variavel <- factor(variavel)

# Gráfico com a quantidade abaixo e acima da média
plot(variavel)

#Visualiza a quantidade abaixo e acima da média
table(variavel)
# Out:
# variavel
# Abaixo_da_media  Acima_da_media
#              19              11
# plot without title

# %%
# Gerar Boxplot das vendas

boxplot(dados$Vendas_Cafe)
# Out:
# plot without title

# %%
# Gerar Boxplot do preço

boxplot(dados$Preco_Cafe)
# Out:
# plot without title

# %%
# Gerar boxplot comparativo das vendas quando houve promoção e de quando não houve

boxplot(dados$Vendas_Cafe~dados$Promocao)
# Out:
# plot without title

# %%
# Customizando o último boxplot

boxplot(dados$Vendas_Cafe~dados$Promocao,
        col = 'gray',
        pch = 16,
        xlab = 'Promoção',
        ylab = 'Vendas',
        main = 'Vendas com promoção vs Vendas sem promoção')
# Out:
# Plot with title “Vendas com promoção vs Vendas sem promoção”
